# %% [markdown]
# <a href="https://colab.research.google.com/github/NaviinRaghav/unimentor/blob/main/Project_2_%E2%80%93_Customer_Satisfaction_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import seaborn as sns
import matplotlib.pyplot as plt

# Example data
y_true = [1,0,1,1,0,1,0,1,0,1]
y_pred = [1,0,1,0,0,1,1,1,0,0]

# Confusion Matrix
cm = confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap="Blues")
plt.show()

# Bar Chart - Feature Importance
importances = [0.3, 0.2, 0.25, 0.25]
features = ["Product Quality","Service","Response Time","Price"]

sns.barplot(x=importances, y=features)
plt.title("Feature Importance for Customer Satisfaction")
plt.show()

# %%
# !pip install streamlit plotly-express
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 76.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 97.5 MB/s eta 0:00:00
# ...

# %%
import streamlit as st
import plotly.express as px

st.title("😊 Customer Satisfaction Dashboard")

satisfaction_data = {"Feature":["Product Quality","Service","Response Time","Price"],
                     "Importance":[0.3,0.25,0.2,0.25]}

fig = px.bar(satisfaction_data, x="Importance", y="Feature", orientation='h',
             title="Feature Importance for Satisfaction")
st.plotly_chart(fig)
# Out:
# 2025-09-14 15:49:32.856 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-14 15:49:33.047
# ...
#   command:
#
#     streamlit run /usr/local/lib/python3.12/dist-packages/colab_kernel_launcher.py [ARGUMENTS]
# 2025-09-14 15:49:33.048 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-14 15:49:33.049 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-14 15:49:33.575 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-14 15:49:33.576 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-14 15:49:33.578 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...
